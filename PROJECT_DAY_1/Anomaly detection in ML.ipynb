# %% [markdown]
# # import python packages

# %%
import os
import sys
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from scipy.io import loadmat

# %% [markdown]
# # import pyod packages and methods

# %%
from pyod.models.pca import PCA
from pyod.models.mcd import MCD
from pyod.models.ocsvm import OCSVM
from pyod.models.lof import LOF
from pyod.models.cblof import CBLOF
from pyod.models.knn import KNN
from pyod.models.hbos import HBOS
from pyod.models.abod import ABOD
from pyod.models.iforest import IForest
from pyod.models.feature_bagging import FeatureBagging
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
#  # import metrics packages

# %%
from pyod.utils.utility import standardizer
from pyod.utils.utility import precision_n_scores
from sklearn.metrics import roc_auc_score

# %% [markdown]
# # Define data file and read X and y

# %%
mat_file_list=['arrhythmia.mat','cardio.mat','glass.mat','ionosphere.mat','letter.mat','mnist.mat','musk.mat','optdigits.mat','pendigits.mat','pima.mat','satellite.mat','satimage-2.mat','shuttle.mat','vertebral.mat','vowels.mat','wbc.mat']

# %%
mat_file_list
# Out:
# ['arrhythmia.mat',
#  'cardio.mat',
#  'glass.mat',
#  'ionosphere.mat',
#  'letter.mat',
#  'mnist.mat',
#  'musk.mat',
#  'optdigits.mat',
#  'pendigits.mat',
#  'pima.mat',
#  'satellite.mat',
#  'satimage-2.mat',
#  'shuttle.mat',
#  'vertebral.mat',
#  'vowels.mat',
#  'wbc.mat']

# %% [markdown]
# # how to load mat file

# %%
data=loadmat("E:\LetsUpgrade AI-ML\PROJECT DAY-1\cardio.mat")

# %%
data
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, written by Octave 3.8.0, 2014-12-18 10:48:09 UTC',
#  '__version__': '1.0',
#  '__globals__': [],
#  'X': array([[ 0.00491231,  0.69319077, -0.20364049, ...,  0.23149795,
#          -0.28978574, -0.49329397],
#         [ 0.11072935, -0.07990259, -0.20364049, ...,  0.09356344,
#          -0.25638541, -0.49329397],
#         [ 0.21654639, -0.27244466, -0.20364049, ...,  0.02459619,
#          -0.25638541,  1.14001753],
#         ...,
#         [-0.41835583, -0.91998844, -0.16463485, ..., -1.49268341,
#           0.24461959, -0.49329397],
#         [-0.41835583, -0.91998844, -0.15093411, ..., -1.42371616,
#           0.14441859, -0.49329397],
#         [-0.41835583, -0.91998844, -0.20364049, ..., -1.28578165,
#           3.58465295, -0.49329397]]),
#  'y': array([[0.],
#         [0.],
#         [0.],
#         ...,
#         [1.],
#         [1.],
#         [1.]])}

# %%
len(data)
# Out:
# 5

# %%
data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'X', 'y'])

# %%
data.values()
# Out:
# dict_values([b'MATLAB 5.0 MAT-file, written by Octave 3.8.0, 2014-12-18 10:48:09 UTC', '1.0', [], array([[ 0.00491231,  0.69319077, -0.20364049, ...,  0.23149795,
#         -0.28978574, -0.49329397],
#        [ 0.11072935, -0.07990259, -0.20364049, ...,  0.09356344,
#         -0.25638541, -0.49329397],
#        [ 0.21654639, -0.27244466, -0.20364049, ...,  0.02459619,
#         -0.25638541,  1.14001753],
#        ...,
#        [-0.41835583, -0.91998844, -0.16463485, ..., -1.49268341,
#          0.24461959, -0.49329397],
#        [-0.41835583, -0.91998844, -0.15093411, ..., -1.42371616,
#          0.14441859, -0.49329397],
#        [-0.41835583, -0.91998844, -0.20364049, ..., -1.28578165,
#          3.58465295, -0.49329397]]), array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [1.],
#        [1.],
#        [1.]])])

# %% [markdown]
# # input feature shape

# %%
type(data['X']),data['X'].shape
# Out:
# (numpy.ndarray, (1831, 21))

# %% [markdown]
# # output feature shape

# %%
type(data['y']),data['y'].shape
# Out:
# (numpy.ndarray, (1831, 1))

# %%
df_columns =['Data','#Samples','# Dimensions','Outlier Perc','ABOD','CBLOF','FB','HBOS','IForest','KNN','LOF','MCD','OCSVM','PCA']

# %% [markdown]
# # ROC performance evolution table

# %%
roc_df=pd.DataFrame(columns=df_columns)

# %%
roc_df
# Out:
# Empty DataFrame
# Columns: [Data, #Samples, # Dimensions, Outlier Perc, ABOD, CBLOF, FB, HBOS, IForest, KNN, LOF, MCD, OCSVM, PCA]
# Index: []

# %% [markdown]
# # precision_n_scores -Performance evolution table

# %%
prn_df=pd.DataFrame(columns=df_columns)
prn_df
# Out:
# Empty DataFrame
# Columns: [Data, #Samples, # Dimensions, Outlier Perc, ABOD, CBLOF, FB, HBOS, IForest, KNN, LOF, MCD, OCSVM, PCA]
# Index: []

# %% [markdown]
# # time dataframe

# %%
time_df=pd.DataFrame(columns=df_columns)
time_df
# Out:
# Empty DataFrame
# Columns: [Data, #Samples, # Dimensions, Outlier Perc, ABOD, CBLOF, FB, HBOS, IForest, KNN, LOF, MCD, OCSVM, PCA]
# Index: []

# %% [markdown]
# # Exploring all mat files

# %%
import time 
for mat_file in mat_file_list:
    print("\n... Processing",mat_file,'...')
    mat = loadmat(os.path.join('E:\LetsUpgrade AI-ML\PROJECT DAY-1',mat_file))
    
    X= mat['X']
    y= mat['y'].ravel()
    outliers_fraction = np.count_nonzero(y)/len(y)
    outliers_percentage=round(outliers_fraction*100,ndigits=4)
    
    #Construct containers for saving result
    roc_list=[mat_file[:-4],X.shape[0],X.shape[1],outliers_percentage]
    prn_list=[mat_file[:-4],X.shape[0],X.shape[1],outliers_percentage]
    time_list=[mat_file[:-4],X.shape[0],X.shape[1],outliers_percentage]

    #60% data for trainin g and 40% for testing
    random_state=np.random.RandomState(42)
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=random_state)
    
    #Standardizing data for processing
    X_train_norm,X_test_norm=standardizer(X_train,X_test)
    classifiers={'Angle-based Outlier Detector (ABOD)' : ABOD(contamination=outliers_fraction),
                 'Cluster-based Local Outlier Factor' : CBLOF(contamination=outliers_fraction,check_estimator=False,random_state=random_state),
                 'Feature Bagging' : FeatureBagging(contamination=outliers_fraction,random_state=random_state),
                 'Histogram-base Outlier Detection (HBOS)' : HBOS(contamination=outliers_fraction),
                 'Isolation Forest' : IForest(contamination=outliers_fraction, random_state=random_state),
                 'K Nearest Neignors (KNN)' : KNN(contamination=outliers_fraction),
                 'Local Outlier Factor (LOF)' : LOF(contamination=outliers_fraction),
                 'Minimum Covariance Determinat (MCD)' : MCD(contamination=outliers_fraction, random_state=random_state),
                 'One-class SVM (OCSVM)' : OCSVM(contamination=outliers_fraction),
                 'Principal Component Ananlysis (PCA)' : PCA(contamination=outliers_fraction, random_state=random_state),
                }
    for clf_name, clf in classifiers.items():
        t0=time.time() #time before training
        clf.fit(X_train_norm)   #for each algorithm, the model is trained
        test_scores=clf.decision_function(X_test_norm) #testing model score
        t1=time.time() #time for testing or time when testing completed
        duration=round(t1-t0,ndigits=4) #time taken to complete training
        time_list.append(duration)
        roc=round(roc_auc_score(y_test,test_scores),ndigits=4)
        prn=round(precision_n_scores(y_test,test_scores),ndigits=4)
        print('{clf_name} ROC:{roc},precision @ rank n:{prn},' 'execution time : {duration}s'.format(clf_name=clf_name,roc=roc,prn=prn,duration=duration))
        roc_list.append(roc)
        prn_list.append(prn)
        
    temp_df=pd.DataFrame(time_list).transpose()
    temp_df.columns=df_columns
    time_df=pd.concat([time_df,temp_df],axis=0)

    temp_df=pd.DataFrame(roc_list).transpose()
    temp_df.columns=df_columns
    roc_df=pd.concat([roc_df,temp_df],axis=0)

    temp_df=pd.DataFrame(prn_list).transpose()
    temp_df.columns=df_columns
    prn_df=pd.concat([prn_df,temp_df],axis=0)
# Out:
# ... Processing arrhythmia.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.7687,precision @ rank n:0.3571,execution time : 0.2414s
# Cluster-based Local Outlier Factor ROC:0.7684,precision @ rank n:0.4643,execution time : 3.5145s
# Feature Bagging ROC:0.7799,precision @ rank n:0.5,execution time : 0.8497s
# Histogram-base Outlier Detection (HBOS) ROC:0.8511,precision @ rank n:0.5714,execution time : 2.2073s
# Isolation Forest ROC:0.8527,precision @ rank n:0.5714,execution time : 0.7104s
# K Nearest Neignors (KNN) ROC:0.782,precision @ rank n:0.5,execution time : 0.1137s
# Local Outlier Factor (LOF) ROC:0.7787,precision @ rank n:0.4643,execution time : 0.12s
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:644: UserWarning: The covariance matrix associated to your dataset is not full rank
#   warnings.warn("The covariance matrix associated to your dataset "
# Minimum Covariance Determinat (MCD) ROC:0.8228,precision @ rank n:0.4286,execution time : 1.5318s
# One-class SVM (OCSVM) ROC:0.7986,precision @ rank n:0.5,execution time : 0.0927s
# Principal Component Ananlysis (PCA) ROC:0.7997,precision @ rank n:0.5,execution time : 0.13s
#
# ... Processing cardio.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.5928,precision @ rank n:0.2838,execution time : 0.5765s
# Cluster-based Local Outlier Factor ROC:0.8547,precision @ rank n:0.5541,execution time : 0.1958s
# Feature Bagging ROC:0.6565,precision @ rank n:0.2297,execution time : 1.4384s
# Histogram-base Outlier Detection (HBOS) ROC:0.87,precision @ rank n:0.5135,execution time : 0.01s
# Isolation Forest ROC:0.9304,precision @ rank n:0.5405,execution time : 0.6562s
# K Nearest Neignors (KNN) ROC:0.7642,precision @ rank n:0.4054,execution time : 0.3103s
# Local Outlier Factor (LOF) ROC:0.6432,precision @ rank n:0.2162,execution time : 0.1794s
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:644: UserWarning: The covariance matrix associated to your dataset is not full rank
#   warnings.warn("The covariance matrix associated to your dataset "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-155.683054484776363 > -233.782932977363458). You may want to try with a higher value of support_fraction (current value: 0.511).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-155.917349977189730 > -235.362429125008902). You may want to try with a higher value of support_fraction (current value: 0.511).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-152.599361413842615 > -222.059282931323736). You may want to try with a higher value of support_fraction (current value: 0.511).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-227.859567128077060 > -229.746480260986914). You may want to try with a higher value of support_fraction (current value: 0.511).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-155.487715639168186 > -222.859022327153667). You may want to try with a higher value of support_fraction (current value: 0.511).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-152.101358123166818 > -224.859189874234659). You may want to try with a higher value of support_fraction (current value: 0.511).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-222.099940991427104 > -223.515854248805596). You may want to try with a higher value of support_fraction (current value: 0.510).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-222.059183928710752 > -222.226316853413692). You may want to try with a higher value of support_fraction (current value: 0.510).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-152.979383582323294 > -221.259763233710430). You may want to try with a higher value of support_fraction (current value: 0.510).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-153.504254210185366 > -217.778615777774775). You may want to try with a higher value of support_fraction (current value: 0.510).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-154.479023052950708 > -224.577877400519156). You may want to try with a higher value of support_fraction (current value: 0.510).
#   RuntimeWarning)
# Minimum Covariance Determinat (MCD) ROC:0.811,precision @ rank n:0.4865,execution time : 0.9696s
# One-class SVM (OCSVM) ROC:0.9462,precision @ rank n:0.527,execution time : 0.211s
# Principal Component Ananlysis (PCA) ROC:0.9581,precision @ rank n:0.6216,execution time : 0.0315s
#
# ... Processing glass.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.7805,precision @ rank n:0.25,execution time : 0.1162s
# Cluster-based Local Outlier Factor ROC:0.9024,precision @ rank n:0.25,execution time : 0.1147s
# Feature Bagging ROC:0.8293,precision @ rank n:0.25,execution time : 0.0948s
# Histogram-base Outlier Detection (HBOS) ROC:0.7256,precision @ rank n:0.25,execution time : 0.005s
# Isolation Forest ROC:0.7287,precision @ rank n:0.25,execution time : 0.5523s
# K Nearest Neignors (KNN) ROC:0.8902,precision @ rank n:0.25,execution time : 0.022s
# Local Outlier Factor (LOF) ROC:0.7287,precision @ rank n:0.25,execution time : 0.0129s
# Minimum Covariance Determinat (MCD) ROC:0.7957,precision @ rank n:0.0,execution time : 0.1155s
# One-class SVM (OCSVM) ROC:0.753,precision @ rank n:0.25,execution time : 0.007s
# Principal Component Ananlysis (PCA) ROC:0.747,precision @ rank n:0.25,execution time : 0.004s
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-29.744624141124874 > -93.552983490404344). You may want to try with a higher value of support_fraction (current value: 0.539).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-29.456973809953059 > -93.264867512175542). You may want to try with a higher value of support_fraction (current value: 0.539).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-29.537884733666839 > -93.303896447144169). You may want to try with a higher value of support_fraction (current value: 0.539).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-29.456973809953059 > -93.290201669515966). You may want to try with a higher value of support_fraction (current value: 0.539).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-29.382381110533391 > -93.186741282438433). You may want to try with a higher value of support_fraction (current value: 0.539).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-29.464647391380186 > -93.198137100014492). You may want to try with a higher value of support_fraction (current value: 0.539).
#   RuntimeWarning)
# ... Processing ionosphere.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.9247,precision @ rank n:0.8868,execution time : 0.2015s
# Cluster-based Local Outlier Factor ROC:0.8999,precision @ rank n:0.7925,execution time : 0.1436s
# Feature Bagging ROC:0.9286,precision @ rank n:0.7736,execution time : 0.1312s
# Histogram-base Outlier Detection (HBOS) ROC:0.5154,precision @ rank n:0.3585,execution time : 0.018s
# Isolation Forest ROC:0.8433,precision @ rank n:0.6604,execution time : 0.4182s
# K Nearest Neignors (KNN) ROC:0.9226,precision @ rank n:0.8868,execution time : 0.0243s
# Local Outlier Factor (LOF) ROC:0.9312,precision @ rank n:0.7736,execution time : 0.009s
# Minimum Covariance Determinat (MCD) ROC:0.9657,precision @ rank n:0.8868,execution time : 0.0848s
# One-class SVM (OCSVM) ROC:0.8799,precision @ rank n:0.7736,execution time : 0.007s
# Principal Component Ananlysis (PCA) ROC:0.8068,precision @ rank n:0.6226,execution time : 0.006s
#
# ... Processing letter.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.8949,precision @ rank n:0.3721,execution time : 0.6061s
# Cluster-based Local Outlier Factor ROC:0.7612,precision @ rank n:0.186,execution time : 0.1577s
# Feature Bagging ROC:0.8663,precision @ rank n:0.3721,execution time : 1.0508s
# Histogram-base Outlier Detection (HBOS) ROC:0.6248,precision @ rank n:0.093,execution time : 0.0289s
# Isolation Forest ROC:0.6403,precision @ rank n:0.093,execution time : 0.7801s
# K Nearest Neignors (KNN) ROC:0.8689,precision @ rank n:0.3488,execution time : 0.3232s
# Local Outlier Factor (LOF) ROC:0.8781,precision @ rank n:0.3721,execution time : 0.1558s
# Minimum Covariance Determinat (MCD) ROC:0.8119,precision @ rank n:0.186,execution time : 2.1324s
# One-class SVM (OCSVM) ROC:0.5827,precision @ rank n:0.1395,execution time : 0.1835s
# Principal Component Ananlysis (PCA) ROC:0.5142,precision @ rank n:0.1163,execution time : 0.017s
#
# ... Processing mnist.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.7682,precision @ rank n:0.3643,execution time : 14.1372s
# Cluster-based Local Outlier Factor ROC:0.8339,precision @ rank n:0.3941,execution time : 2.3444s
# Feature Bagging ROC:0.6936,precision @ rank n:0.3234,execution time : 69.9805s
# Histogram-base Outlier Detection (HBOS) ROC:0.5578,precision @ rank n:0.0967,execution time : 0.0625s
# Isolation Forest ROC:0.8045,precision @ rank n:0.2714,execution time : 2.874s
# K Nearest Neignors (KNN) ROC:0.8423,precision @ rank n:0.4349,execution time : 10.0242s
# Local Outlier Factor (LOF) ROC:0.7012,precision @ rank n:0.3309,execution time : 9.1175s
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:644: UserWarning: The covariance matrix associated to your dataset is not full rank
#   warnings.warn("The covariance matrix associated to your dataset "
# Minimum Covariance Determinat (MCD) ROC:0.8553,precision @ rank n:0.2268,execution time : 4.1109s
# One-class SVM (OCSVM) ROC:0.8622,precision @ rank n:0.4015,execution time : 6.9991s
# Principal Component Ananlysis (PCA) ROC:0.8613,precision @ rank n:0.3903,execution time : 0.3185s
#
# ... Processing musk.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.1012,precision @ rank n:0.0294,execution time : 3.7814s
# Cluster-based Local Outlier Factor ROC:1.0,precision @ rank n:1.0,execution time : 0.6233s
# Feature Bagging ROC:0.5705,precision @ rank n:0.1471,execution time : 19.4184s
# Histogram-base Outlier Detection (HBOS) ROC:1.0,precision @ rank n:1.0,execution time : 0.0848s
# Isolation Forest ROC:1.0,precision @ rank n:0.9706,execution time : 1.8521s
# K Nearest Neignors (KNN) ROC:0.7729,precision @ rank n:0.2059,execution time : 2.8354s
# Local Outlier Factor (LOF) ROC:0.5567,precision @ rank n:0.1471,execution time : 2.4991s
# Minimum Covariance Determinat (MCD) ROC:1.0,precision @ rank n:1.0,execution time : 15.9414s
# One-class SVM (OCSVM) ROC:1.0,precision @ rank n:1.0,execution time : 1.941s
# Principal Component Ananlysis (PCA) ROC:1.0,precision @ rank n:1.0,execution time : 0.1995s
#
# ... Processing optdigits.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.4601,precision @ rank n:0.0,execution time : 3.6194s
# Cluster-based Local Outlier Factor ROC:0.7515,precision @ rank n:0.0,execution time : 0.6365s
# Feature Bagging ROC:0.4197,precision @ rank n:0.0164,execution time : 17.8399s
# Histogram-base Outlier Detection (HBOS) ROC:0.8962,precision @ rank n:0.1803,execution time : 0.0469s
# Isolation Forest ROC:0.6531,precision @ rank n:0.0164,execution time : 1.422s
# K Nearest Neignors (KNN) ROC:0.3717,precision @ rank n:0.0,execution time : 2.5213s
# Local Outlier Factor (LOF) ROC:0.4191,precision @ rank n:0.0164,execution time : 2.2622s
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:644: UserWarning: The covariance matrix associated to your dataset is not full rank
#   warnings.warn("The covariance matrix associated to your dataset "
# Minimum Covariance Determinat (MCD) ROC:0.4226,precision @ rank n:0.0,execution time : 1.631s
# One-class SVM (OCSVM) ROC:0.4817,precision @ rank n:0.0,execution time : 1.9398s
# Principal Component Ananlysis (PCA) ROC:0.507,precision @ rank n:0.0,execution time : 0.0646s
#
# ... Processing pendigits.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.677,precision @ rank n:0.0725,execution time : 2.1809s
# Cluster-based Local Outlier Factor ROC:0.8488,precision @ rank n:0.2029,execution time : 0.3415s
# Feature Bagging ROC:0.4674,precision @ rank n:0.0725,execution time : 4.4055s
# Histogram-base Outlier Detection (HBOS) ROC:0.9261,precision @ rank n:0.2609,execution time : 0.0289s
# Isolation Forest ROC:0.9555,precision @ rank n:0.3768,execution time : 1.0289s
# K Nearest Neignors (KNN) ROC:0.7603,precision @ rank n:0.1594,execution time : 0.8644s
# Local Outlier Factor (LOF) ROC:0.4578,precision @ rank n:0.0725,execution time : 0.7898s
# Minimum Covariance Determinat (MCD) ROC:0.8387,precision @ rank n:0.1159,execution time : 2.3279s
# One-class SVM (OCSVM) ROC:0.946,precision @ rank n:0.3333,execution time : 1.2462s
# Principal Component Ananlysis (PCA) ROC:0.9402,precision @ rank n:0.3478,execution time : 0.014s
#
# ... Processing pima.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.665,precision @ rank n:0.4314,execution time : 0.2065s
# Cluster-based Local Outlier Factor ROC:0.6724,precision @ rank n:0.4608,execution time : 0.1107s
# Feature Bagging ROC:0.6551,precision @ rank n:0.4608,execution time : 0.1388s
# Histogram-base Outlier Detection (HBOS) ROC:0.7029,precision @ rank n:0.5392,execution time : 0.004s
# Isolation Forest ROC:0.6843,precision @ rank n:0.4608,execution time : 0.4568s
# K Nearest Neignors (KNN) ROC:0.7123,precision @ rank n:0.5,execution time : 0.0469s
# Local Outlier Factor (LOF) ROC:0.6621,precision @ rank n:0.4706,execution time : 0.015s
# Minimum Covariance Determinat (MCD) ROC:0.6942,precision @ rank n:0.4706,execution time : 0.0758s
# One-class SVM (OCSVM) ROC:0.6423,precision @ rank n:0.4412,execution time : 0.015s
# Principal Component Ananlysis (PCA) ROC:0.6444,precision @ rank n:0.451,execution time : 0.002s
#
# ... Processing satellite.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.5598,precision @ rank n:0.3723,execution time : 2.7185s
# Cluster-based Local Outlier Factor ROC:0.7117,precision @ rank n:0.5321,execution time : 0.4897s
# Feature Bagging ROC:0.5331,precision @ rank n:0.3597,execution time : 9.5277s
# Histogram-base Outlier Detection (HBOS) ROC:0.7574,precision @ rank n:0.5585,execution time : 0.028s
# Isolation Forest ROC:0.7113,precision @ rank n:0.5497,execution time : 1.1773s
# K Nearest Neignors (KNN) ROC:0.6755,precision @ rank n:0.4818,execution time : 1.5678s
# Local Outlier Factor (LOF) ROC:0.5339,precision @ rank n:0.3572,execution time : 1.4016s
# Minimum Covariance Determinat (MCD) ROC:0.7863,precision @ rank n:0.6692,execution time : 2.9305s
# One-class SVM (OCSVM) ROC:0.6437,precision @ rank n:0.5119,execution time : 1.7853s
# Principal Component Ananlysis (PCA) ROC:0.5762,precision @ rank n:0.4642,execution time : 0.0369s
#
# ... Processing satimage-2.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.8675,precision @ rank n:0.3333,execution time : 2.7005s
# Cluster-based Local Outlier Factor ROC:0.9998,precision @ rank n:0.9259,execution time : 0.4456s
# Feature Bagging ROC:0.573,precision @ rank n:0.1111,execution time : 7.9572s
# Histogram-base Outlier Detection (HBOS) ROC:0.9809,precision @ rank n:0.6667,execution time : 0.0156s
# Isolation Forest ROC:0.9951,precision @ rank n:0.8148,execution time : 1.0528s
# K Nearest Neignors (KNN) ROC:0.9595,precision @ rank n:0.4444,execution time : 1.5319s
# Local Outlier Factor (LOF) ROC:0.5699,precision @ rank n:0.1111,execution time : 1.1951s
# Minimum Covariance Determinat (MCD) ROC:0.9964,precision @ rank n:0.6296,execution time : 3.1738s
# One-class SVM (OCSVM) ROC:0.9997,precision @ rank n:0.8889,execution time : 1.4985s
# Principal Component Ananlysis (PCA) ROC:0.9834,precision @ rank n:0.8148,execution time : 0.0312s
#
# ... Processing shuttle.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.6096,precision @ rank n:0.1853,execution time : 21.2681s
# Cluster-based Local Outlier Factor ROC:0.602,precision @ rank n:0.2189,execution time : 1.2417s
# Feature Bagging ROC:0.4735,precision @ rank n:0.0701,execution time : 83.9131s
# Histogram-base Outlier Detection (HBOS) ROC:0.9842,precision @ rank n:0.9896,execution time : 0.0389s
# Isolation Forest ROC:0.9973,precision @ rank n:0.9571,execution time : 5.1201s
# K Nearest Neignors (KNN) ROC:0.643,precision @ rank n:0.2153,execution time : 12.3267s
# Local Outlier Factor (LOF) ROC:0.529,precision @ rank n:0.1323,execution time : 14.9308s
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.015419314992862 > -77.703198913328549). You may want to try with a higher value of support_fraction (current value: 0.503).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-51.056909975554191 > -77.324765861735116). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-51.506791553473228 > -80.045464139191353). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.943212765343688 > -76.629734979619514). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.452643627402345 > -77.716844960427366). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.571698750426734 > -77.399032302546900). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.522976523651359 > -79.146767532045359). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.707105184494701 > -75.878642585482211). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-51.719571273942634 > -79.982421213381315). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.591734819743706 > -78.118471170975155). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.868351361592985 > -75.457808493890838). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-51.070472587660696 > -77.681288841356164). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-51.750203866498552 > -78.874758353322534). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.026801085015336 > -75.343716916844798). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.252079764007846 > -81.102698967535289). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-51.326044326567072 > -78.436701304842558). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.046284772693568 > -75.804162283688299). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.766392078685477 > -75.921449582815768). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.669886346304068 > -75.965763743684249). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.445945615387387 > -76.830768800359266). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.714206729042672 > -76.794548375532173). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.990263161088734 > -76.723776741553465). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.953780527540744 > -78.048056725825759). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.716198702885350 > -77.110709462845179). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.638097464380571 > -78.147934726653432). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.931896538580553 > -76.194028921274551). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.939991729478855 > -79.537540146705282). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.964637824590369 > -76.683283077123662). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-51.184446302729427 > -77.408457350693141). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.681310207060633 > -77.540552060931390). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-51.288149560556171 > -77.089268317194183). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-51.273358323629012 > -78.876800366788316). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.228574063754145 > -79.876796846434175). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.993842880553196 > -77.782658839185999). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-51.023652254712545 > -77.779382230862367). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.783830710780101 > -77.287585929459510). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# Minimum Covariance Determinat (MCD) ROC:0.9901,precision @ rank n:0.7332,execution time : 12.2186s
# One-class SVM (OCSVM) ROC:0.9922,precision @ rank n:0.9578,execution time : 63.2183s
# Principal Component Ananlysis (PCA) ROC:0.9904,precision @ rank n:0.9542,execution time : 0.0312s
#
# ... Processing vertebral.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.3968,precision @ rank n:0.0909,execution time : 0.0781s
# Cluster-based Local Outlier Factor ROC:0.3882,precision @ rank n:0.0,execution time : 0.0698s
# Feature Bagging ROC:0.4289,precision @ rank n:0.0909,execution time : 0.0469s
# Histogram-base Outlier Detection (HBOS) ROC:0.3166,precision @ rank n:0.0,execution time : 0.0s
# Isolation Forest ROC:0.3444,precision @ rank n:0.0,execution time : 0.3695s
# K Nearest Neignors (KNN) ROC:0.384,precision @ rank n:0.0,execution time : 0.0156s
# Local Outlier Factor (LOF) ROC:0.4342,precision @ rank n:0.0909,execution time : 0.0s
# Minimum Covariance Determinat (MCD) ROC:0.4214,precision @ rank n:0.0,execution time : 0.0937s
# One-class SVM (OCSVM) ROC:0.3947,precision @ rank n:0.0909,execution time : 0.0156s
# Principal Component Ananlysis (PCA) ROC:0.3615,precision @ rank n:0.0,execution time : 0.0s
#
# ... Processing vowels.mat ...
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-23.125078286203880 > -42.193997637653659). You may want to try with a higher value of support_fraction (current value: 0.528).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-23.203296655673416 > -40.407112650254476). You may want to try with a higher value of support_fraction (current value: 0.528).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-22.994244185500083 > -40.603416206306314). You may want to try with a higher value of support_fraction (current value: 0.528).
#   RuntimeWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-23.349846719521246 > -42.402611498304871). You may want to try with a higher value of support_fraction (current value: 0.528).
#   RuntimeWarning)
# Angle-based Outlier Detector (ABOD) ROC:0.9515,precision @ rank n:0.5,execution time : 0.3909s
# Cluster-based Local Outlier Factor ROC:0.9419,precision @ rank n:0.2727,execution time : 0.0937s
# Feature Bagging ROC:0.943,precision @ rank n:0.2273,execution time : 0.3636s
# Histogram-base Outlier Detection (HBOS) ROC:0.6365,precision @ rank n:0.0,execution time : 0.006s
# Isolation Forest ROC:0.7601,precision @ rank n:0.1364,execution time : 0.4748s
# K Nearest Neignors (KNN) ROC:0.9763,precision @ rank n:0.4545,execution time : 0.0948s
# Local Outlier Factor (LOF) ROC:0.9119,precision @ rank n:0.2727,execution time : 0.0439s
# Minimum Covariance Determinat (MCD) ROC:0.6877,precision @ rank n:0.0455,execution time : 0.9298s
# One-class SVM (OCSVM) ROC:0.7763,precision @ rank n:0.1364,execution time : 0.0781s
# Principal Component Ananlysis (PCA) ROC:0.5675,precision @ rank n:0.0909,execution time : 0.0s
#
# ... Processing wbc.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.9181,precision @ rank n:0.5455,execution time : 0.0918s
# Cluster-based Local Outlier Factor ROC:0.9259,precision @ rank n:0.5455,execution time : 0.0718s
# Feature Bagging ROC:0.9555,precision @ rank n:0.7273,execution time : 0.0967s
# Histogram-base Outlier Detection (HBOS) ROC:0.9594,precision @ rank n:0.6364,execution time : 0.012s
# Isolation Forest ROC:0.9355,precision @ rank n:0.6364,execution time : 0.399s
# K Nearest Neignors (KNN) ROC:0.9426,precision @ rank n:0.7273,execution time : 0.026s
# Local Outlier Factor (LOF) ROC:0.9536,precision @ rank n:0.6364,execution time : 0.01s
# Minimum Covariance Determinat (MCD) ROC:0.9233,precision @ rank n:0.5455,execution time : 0.0778s
# One-class SVM (OCSVM) ROC:0.9433,precision @ rank n:0.6364,execution time : 0.01s
# Principal Component Ananlysis (PCA) ROC:0.9329,precision @ rank n:0.6364,execution time : 0.003s

# %%
roc_df
# Out:
#          Data #Samples # Dimensions Outlier Perc    ABOD   CBLOF      FB  \
# 0  arrhythmia      452          274      14.6018  0.7687  0.7684  0.7799
# 0      cardio     1831           21       9.6122  0.5928  0.8547  0.6565
# 0       glass      214            9       4.2056  0.7805  0.9024  0.8293
# 0  ionosphere      351           33      35.8974  0.9247  0.8999  0.9286
# 0      letter     1600           32         6.25  0.8949  0.7612  0.8663
# 0       mnist     7603          100       9.2069  0.7682  0.8339  0.6936
# 0        musk     3062          166       3.1679  0.1012       1  0.5705
# 0   optdigits     5216           64       2.8758  0.4601  0.7515  0.4197
# 0   pendigits     6870           16       2.2707   0.677  0.8488  0.4674
# 0        pima      768            8      34.8958   0.665  0.6724  0.6551
# 0   satellite     6435           36      31.6395  0.5598  0.7117  0.5331
# 0  satimage-2     5803           36       1.2235  0.8675  0.9998   0.573
# 0     shuttle    49097            9       7.1511  0.6096   0.602  0.4735
# 0   vertebral      240            6         12.5  0.3968  0.3882  0.4289
# 0      vowels     1456           12       3.4341  0.9515  0.9419   0.943
# 0         wbc      378           30       5.5556  0.9181  0.9259  0.9555
#
#      HBOS IForest     KNN     LOF     MCD   OCSVM     PCA
# 0  0.8511  0.8527   0.782  0.7787  0.8228  0.7986  0.7997
# 0    0.87  0.9304  0.7642  0.6432   0.811  0.9462  0.9581
# 0  0.7256  0.7287  0.8902  0.7287  0.7957   0.753   0.747
# 0  0.5154  0.8433  0.9226  0.9312  0.9657  0.8799  0.8068
# 0  0.6248  0.6403  0.8689  0.8781  0.8119  0.5827  0.5142
# 0  0.5578  0.8045  0.8423  0.7012  0.8553  0.8622  0.8613
# 0       1       1  0.7729  0.5567       1       1       1
# 0  0.8962  0.6531  0.3717  0.4191  0.4226  0.4817   0.507
# 0  0.9261  0.9555  0.7603  0.4578  0.8387   0.946  0.9402
# 0  0.7029  0.6843  0.7123  0.6621  0.6942  0.6423  0.6444
# 0  0.7574  0.7113  0.6755  0.5339  0.7863  0.6437  0.5762
# 0  0.9809  0.9951  0.9595  0.5699  0.9964  0.9997  0.9834
# 0  0.9842  0.9973   0.643   0.529  0.9901  0.9922  0.9904
# 0  0.3166  0.3444   0.384  0.4342  0.4214  0.3947  0.3615
# 0  0.6365  0.7601  0.9763  0.9119  0.6877  0.7763  0.5675
# 0  0.9594  0.9355  0.9426  0.9536  0.9233  0.9433  0.9329

# %%
time_df
# Out:
#          Data #Samples # Dimensions Outlier Perc     ABOD   CBLOF       FB  \
# 0  arrhythmia      452          274      14.6018   0.2414  3.5145   0.8497
# 0      cardio     1831           21       9.6122   0.5765  0.1958   1.4384
# 0       glass      214            9       4.2056   0.1162  0.1147   0.0948
# 0  ionosphere      351           33      35.8974   0.2015  0.1436   0.1312
# 0      letter     1600           32         6.25   0.6061  0.1577   1.0508
# 0       mnist     7603          100       9.2069  14.1372  2.3444  69.9805
# 0        musk     3062          166       3.1679   3.7814  0.6233  19.4184
# 0   optdigits     5216           64       2.8758   3.6194  0.6365  17.8399
# 0   pendigits     6870           16       2.2707   2.1809  0.3415   4.4055
# 0        pima      768            8      34.8958   0.2065  0.1107   0.1388
# 0   satellite     6435           36      31.6395   2.7185  0.4897   9.5277
# 0  satimage-2     5803           36       1.2235   2.7005  0.4456   7.9572
# 0     shuttle    49097            9       7.1511  21.2681  1.2417  83.9131
# 0   vertebral      240            6         12.5   0.0781  0.0698   0.0469
# 0      vowels     1456           12       3.4341   0.3909  0.0937   0.3636
# 0         wbc      378           30       5.5556   0.0918  0.0718   0.0967
#
#      HBOS IForest      KNN      LOF      MCD    OCSVM     PCA
# 0  2.2073  0.7104   0.1137     0.12   1.5318   0.0927    0.13
# 0    0.01  0.6562   0.3103   0.1794   0.9696    0.211  0.0315
# 0   0.005  0.5523    0.022   0.0129   0.1155    0.007   0.004
# 0   0.018  0.4182   0.0243    0.009   0.0848    0.007   0.006
# 0  0.0289  0.7801   0.3232   0.1558   2.1324   0.1835   0.017
# 0  0.0625   2.874  10.0242   9.1175   4.1109   6.9991  0.3185
# 0  0.0848  1.8521   2.8354   2.4991  15.9414    1.941  0.1995
# 0  0.0469   1.422   2.5213   2.2622    1.631   1.9398  0.0646
# 0  0.0289  1.0289   0.8644   0.7898   2.3279   1.2462   0.014
# 0   0.004  0.4568   0.0469    0.015   0.0758    0.015   0.002
# 0   0.028  1.1773   1.5678   1.4016   2.9305   1.7853  0.0369
# 0  0.0156  1.0528   1.5319   1.1951   3.1738   1.4985  0.0312
# 0  0.0389  5.1201  12.3267  14.9308  12.2186  63.2183  0.0312
# 0       0  0.3695   0.0156        0   0.0937   0.0156       0
# 0   0.006  0.4748   0.0948   0.0439   0.9298   0.0781       0
# 0   0.012   0.399    0.026     0.01   0.0778     0.01   0.003

# %%
prn_df
# Out:
#          Data #Samples # Dimensions Outlier Perc    ABOD   CBLOF      FB  \
# 0  arrhythmia      452          274      14.6018  0.3571  0.4643     0.5
# 0      cardio     1831           21       9.6122  0.2838  0.5541  0.2297
# 0       glass      214            9       4.2056    0.25    0.25    0.25
# 0  ionosphere      351           33      35.8974  0.8868  0.7925  0.7736
# 0      letter     1600           32         6.25  0.3721   0.186  0.3721
# 0       mnist     7603          100       9.2069  0.3643  0.3941  0.3234
# 0        musk     3062          166       3.1679  0.0294       1  0.1471
# 0   optdigits     5216           64       2.8758       0       0  0.0164
# 0   pendigits     6870           16       2.2707  0.0725  0.2029  0.0725
# 0        pima      768            8      34.8958  0.4314  0.4608  0.4608
# 0   satellite     6435           36      31.6395  0.3723  0.5321  0.3597
# 0  satimage-2     5803           36       1.2235  0.3333  0.9259  0.1111
# 0     shuttle    49097            9       7.1511  0.1853  0.2189  0.0701
# 0   vertebral      240            6         12.5  0.0909       0  0.0909
# 0      vowels     1456           12       3.4341     0.5  0.2727  0.2273
# 0         wbc      378           30       5.5556  0.5455  0.5455  0.7273
#
#      HBOS IForest     KNN     LOF     MCD   OCSVM     PCA
# 0  0.5714  0.5714     0.5  0.4643  0.4286     0.5     0.5
# 0  0.5135  0.5405  0.4054  0.2162  0.4865   0.527  0.6216
# 0    0.25    0.25    0.25    0.25       0    0.25    0.25
# 0  0.3585  0.6604  0.8868  0.7736  0.8868  0.7736  0.6226
# 0   0.093   0.093  0.3488  0.3721   0.186  0.1395  0.1163
# 0  0.0967  0.2714  0.4349  0.3309  0.2268  0.4015  0.3903
# 0       1  0.9706  0.2059  0.1471       1       1       1
# 0  0.1803  0.0164       0  0.0164       0       0       0
# 0  0.2609  0.3768  0.1594  0.0725  0.1159  0.3333  0.3478
# 0  0.5392  0.4608     0.5  0.4706  0.4706  0.4412   0.451
# 0  0.5585  0.5497  0.4818  0.3572  0.6692  0.5119  0.4642
# 0  0.6667  0.8148  0.4444  0.1111  0.6296  0.8889  0.8148
# 0  0.9896  0.9571  0.2153  0.1323  0.7332  0.9578  0.9542
# 0       0       0       0  0.0909       0  0.0909       0
# 0       0  0.1364  0.4545  0.2727  0.0455  0.1364  0.0909
# 0  0.6364  0.6364  0.7273  0.6364  0.5455  0.6364  0.6364
